# %%
import pandas as pd
import os

# %%
testing_dirs: list[str] = sorted(["data/" + d for d in os.listdir(path="data/")])

# %%
testing_dirs
# Out:
# ['data/lunar_test_12_b_00006.json',
#  'data/lunar_test_12_b_00007.json',
#  'data/lunar_test_12_b_00014.json',
#  'data/lunar_test_12_b_00016.json',
#  'data/lunar_test_12_b_00018.json',
#  'data/lunar_test_12_b_00020.json',
#  'data/lunar_test_12_b_00021.json',
#  'data/lunar_test_12_b_00026.json',
#  'data/lunar_test_12_b_00027.json',
#  'data/lunar_test_12_b_00028.json',
#  'data/lunar_test_12_b_00029.json',
#  'data/lunar_test_12_b_00031.json',
#  'data/lunar_test_12_b_00035.json',
#  'data/lunar_test_12_b_00036.json',
#  'data/lunar_test_12_b_00037.json',
#  'data/lunar_test_12_b_00039.json',
#  'data/lunar_test_12_b_00043.json',
#  'data/lunar_test_12_b_00049.json',
#  'data/lunar_test_12_b_00050.json',
#  'data/lunar_test_12_b_00051.json',
#  'data/lunar_test_12_b_00057.json',
#  'data/lunar_test_12_b_00059.json',
#  'data/lunar_test_12_b_00060.json',
#  'data/lunar_test_12_b_00073.json',
#  'data/lunar_test_12_b_00083.json',
#  'data/lunar_test_12_b_00092.json',
# ...

# %%
lunar_train: pd.DataFrame = pd.read_json(path_or_buf="data/lunar_train_12_a_00002.json")

# %%
lunar_train
# Out:
#         time_rel      velocity
# 0          73500 -6.153279e-14
# 1          73500 -7.701288e-14
# 2          73500 -8.396187e-14
# 3          73500 -8.096155e-14
# 4          73500 -7.097599e-14
# ...          ...           ...
# 572410     73500 -1.472713e-14
# 572411     73500 -1.956104e-14
# 572412     73500 -2.240307e-14
# 572413     73500 -2.998405e-14
# 572414     73500 -4.465515e-14
#
# [572415 rows x 2 columns]

# %%
lunar_train['velocity'].plot()
# Out:
# <Axes: >
